# %%
import pandas as pd
df=pd.read_csv("Weather Dataset (1).csv")

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01/01/2012 00:00    -1.8              -3.9         86                4
# 1     01/01/2012 01:00    -1.8              -3.7         87                4
# 2     01/01/2012 02:00    -1.8              -3.4         89                7
# 3     01/01/2012 03:00    -1.5              -3.2         88                6
# 4     01/01/2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.head(3)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01/01/2012 00:00    -1.8              -3.9         86                4
# 1  01/01/2012 01:00    -1.8              -3.7         87                4
# 2  01/01/2012 02:00    -1.8              -3.4         89                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 8

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.Weather
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.count().plot(kind='pie');

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df["Weather"].value_counts().plot(kind='bar');

# %%
df.info(max_cols=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Columns: 8 entries, Date/Time to Weather
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.head(1)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01/01/2012 00:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
df["Wind Speed_km/h"].nunique()
# Out:
# 34

# %%
df["Weather"].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df[df.Weather=="Clear"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01/03/2012 19:00   -16.9             -24.8         50               24
# 114   01/05/2012 18:00    -7.1             -14.4         56               11
# 115   01/05/2012 19:00    -9.2             -15.4         61                7
# 116   01/05/2012 20:00    -9.8             -15.7         62                9
# 117   01/05/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
len(df[df.Weather=="Clear"])
# Out:
# 1326

# %%
cl=df.groupby('Weather').get_group('Clear')
cl['Weather'].unique()
# Out:
# array(['Clear'], dtype=object)

# %%
cl=df.groupby('Wind Speed_km/h').get_group(4)
cl
len(cl)
# Out:
# 474

# %%
df.isnull().sum()
#df.isnull()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.rename(columns={"Weather":"Weather_condition"},inplace=True)

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01/01/2012 00:00    -1.8              -3.9         86                4
# 1     01/01/2012 01:00    -1.8              -3.7         87                4
# 2     01/01/2012 02:00    -1.8              -3.4         89                7
# 3     01/01/2012 03:00    -1.5              -3.2         88                6
# 4     01/01/2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#df.Variability_km.mean()
a=len(df["Visibility_km"])
b=sum(df["Visibility_km"])

average=b/a
average
# Out:
# 27.664446721311474

# %%
#m=df.Visibility_km
df.Visibility_km.median()
# Out:
# np.float64(25.0)

# %%
len(df.groupby('Weather_condition').get_group('Snow'))
# Out:
# 390

# %%
df.groupby('Weather_condition').get_group('Snow')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55    01/03/2012 07:00   -14.0             -19.5         63               19
# 84    01/04/2012 12:00   -13.7             -21.7         51               11
# 86    01/04/2012 14:00   -11.3             -19.0         53                7
# 87    01/04/2012 15:00   -10.2             -16.3         61               11
# 88    01/04/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.groupby('Wind Speed_km/h').get_group(24)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 22    01/01/2012 22:00     4.4               1.9         84               24
# 40    01/02/2012 16:00    -0.7              -8.7         55               24
# 43    01/02/2012 19:00    -4.8             -12.1         57               24
# 44    01/02/2012 20:00    -5.6             -13.4         54               24
# 52    01/03/2012 04:00   -12.6             -20.1         53               24
# ...                ...     ...               ...        ...              ...
# 8733  12/29/2012 21:00    -9.8             -11.8         85               24
# 8746  12/30/2012 10:00   -12.4             -16.0         74               24
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
#
# ...

# %%
df.groupby('Visibility_km').get_group(25)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 20    01/01/2012 20:00     3.2               1.3         87               19
# 21    01/01/2012 21:00     4.0               1.7         85               20
# 23    01/01/2012 23:00     5.3               2.0         79               30
# 24    01/02/2012 00:00     5.2               1.5         77               35
# 25    01/02/2012 01:00     4.6               0.0         72               39
# ...                ...     ...               ...        ...              ...
# 8762   12/31/2012 2:00   -10.1             -13.4         77                9
# 8763   12/31/2012 3:00   -11.8             -14.4         81                6
# 8764   12/31/2012 4:00   -10.5             -12.8         83               11
# 8765   12/31/2012 5:00   -10.2             -12.4         84                6
# 8766   12/31/2012 6:00    -9.7             -11.7         85                4
#
# ...

# %%
df[(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23    01/01/2012 23:00     5.3               2.0         79               30
# 24    01/02/2012 00:00     5.2               1.5         77               35
# 25    01/02/2012 01:00     4.6               0.0         72               39
# 26    01/02/2012 02:00     3.9              -0.9         71               32
# 27    01/02/2012 03:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
df["Visibility_km"][0]
# Out:
# np.float64(8.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date/Time          8784 non-null   object
#  1   Temp_C             8784 non-null   float64
#  2   Dew Point Temp_C   8784 non-null   float64
#  3   Rel Hum_%          8784 non-null   int64
#  4   Wind Speed_km/h    8784 non-null   int64
#  5   Visibility_km      8784 non-null   float64
#  6   Press_kPa          8784 non-null   float64
#  7   Weather_condition  8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df["Wind Speed_km/h"].astype(float)
# Out:
# 0        4.0
# 1        4.0
# 2        7.0
# 3        6.0
# 4        7.0
#         ...
# 8779    30.0
# 8780    24.0
# 8781    28.0
# 8782    28.0
# 8783    30.0
# Name: Wind Speed_km/h, Length: 8784, dtype: float64

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01/01/2012 00:00    -1.8              -3.9         86                4
# 1     01/01/2012 01:00    -1.8              -3.7         87                4
# 2     01/01/2012 02:00    -1.8              -3.4         89                7
# 3     01/01/2012 03:00    -1.5              -3.2         88                6
# 4     01/01/2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df["Temp_C"].mean()
# Out:
# np.float64(8.798144353369763)

# %%
df["Dew Point Temp_C"].mean()
# Out:
# np.float64(2.555293715846995)

# %%
df["Rel Hum_%"].mean()
# Out:
# np.float64(67.43169398907104)

# %%
df["Wind Speed_km/h"].mean()
# Out:
# np.float64(14.94546903460838)

# %%
df["Visibility_km"].mean()
# Out:
# np.float64(27.664446721311474)

# %%
df["Press_kPa"].mean()
# Out:
# np.float64(101.05162340619307)

# %%
df2=df.groupby('Weather_condition').get_group("Snow")
df2
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55    01/03/2012 07:00   -14.0             -19.5         63               19
# 84    01/04/2012 12:00   -13.7             -21.7         51               11
# 86    01/04/2012 14:00   -11.3             -19.0         53                7
# 87    01/04/2012 15:00   -10.2             -16.3         61               11
# 88    01/04/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df2["Temp_C"].mean()
# Out:
# np.float64(-4.524102564102565)

# %%
df2["Dew Point Temp_C"].mean()
# Out:
# np.float64(-7.623333333333333)

# %%
df2["Rel Hum_%"].mean()
# Out:
# np.float64(79.3076923076923)

# %%
df2["Wind Speed_km/h"].mean()
# Out:
# np.float64(20.03846153846154)

# %%
df["Visibility_km"].mean()
# Out:
# np.float64(27.664446721311474)

# %%
df["Press_kPa"].mean()
# Out:
# np.float64(101.05162340619307)

# %%
df["Weather_condition"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.groupby("Weather_condition").mean('numeric_only')
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather_condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
df.groupby("Weather_condition").min('numeric_only')
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_condition
# Clear                                     -23.3             -28.5         20
# Cloudy                                    -21.4             -26.8         18
# Drizzle                                     1.1              -0.2         74
# Drizzle,Fog                                 0.0              -1.6         85
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                0.9               0.1         92
# Drizzle,Snow,Fog                            0.3              -0.1         92
# Fog                                       -16.0             -17.2         80
# Freezing Drizzle                           -9.0             -12.2         78
# Freezing Drizzle,Fog                       -6.4              -9.0         82
# Freezing Drizzle,Haze                      -5.8              -8.3         81
# ...

# %%
df.groupby("Weather_condition").max('numeric_only')
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_condition
# Clear                                      32.8              20.4         99
# Cloudy                                     30.5              22.6         99
# Drizzle                                    18.8              17.7         96
# Drizzle,Fog                                19.9              19.1        100
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                1.2               0.2         95
# Drizzle,Snow,Fog                            1.1               0.6         98
# Fog                                        20.8              19.6        100
# Freezing Drizzle                           -2.3              -3.3         93
# Freezing Drizzle,Fog                       -0.3              -2.3         94
# Freezing Drizzle,Haze                      -5.0              -7.7         83
# ...

# %%
df.groupby("Weather_condition").agg(['min', 'max'])
# Out:
#                                                 Date/Time                    \
#                                                       min               max
# Weather_condition
# Clear                                    01/03/2012 19:00    9/28/2012 4:00
# Cloudy                                   01/01/2012 17:00    9/30/2012 9:00
# Drizzle                                  05/01/2012 15:00    9/30/2012 3:00
# Drizzle,Fog                              05/01/2012 16:00    9/30/2012 2:00
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00   12/17/2012 9:00
# Drizzle,Snow                             12/17/2012 15:00  12/19/2012 18:00
# Drizzle,Snow,Fog                         12/18/2012 21:00   12/22/2012 3:00
# Fog                                      01/01/2012 00:00    9/22/2012 0:00
# Freezing Drizzle                         01/07/2012 11:00   12/17/2012 0:00
# Freezing Drizzle,Fog                     01/01/2012 02:00  12/10/2012 05:00
# ...

# %%
df[df.Weather_condition.str.contains("Fog")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01/01/2012 00:00    -1.8              -3.9         86                4
# 1     01/01/2012 01:00    -1.8              -3.7         87                4
# 2     01/01/2012 02:00    -1.8              -3.4         89                7
# 3     01/01/2012 03:00    -1.5              -3.2         88                6
# 4     01/01/2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8739   12/30/2012 3:00    -9.1             -10.4         90               11
# 8740   12/30/2012 4:00    -9.3             -10.6         90               13
# 8741   12/30/2012 5:00    -9.1             -10.4         90               11
# 8742   12/30/2012 6:00    -9.3             -10.8         89               17
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
#
# ...

# %%
df[df.Weather_condition=="Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01/01/2012 00:00    -1.8              -3.9         86                4
# 1     01/01/2012 01:00    -1.8              -3.7         87                4
# 4     01/01/2012 04:00    -1.5              -3.3         88                7
# 5     01/01/2012 05:00    -1.4              -3.3         87                9
# 6     01/01/2012 06:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
df[(df["Weather_condition"]=="Clear") | (df["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01/03/2012 19:00   -16.9             -24.8         50               24
# 106   01/05/2012 10:00    -6.0             -10.0         73               17
# 107   01/05/2012 11:00    -5.6             -10.2         70               22
# 108   01/05/2012 12:00    -4.7              -9.6         69               20
# 109   01/05/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
df[((df["Weather_condition"]=="Clear") & (df["Rel Hum_%"]>50)) | (df["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106   01/05/2012 10:00    -6.0             -10.0         73               17
# 107   01/05/2012 11:00    -5.6             -10.2         70               22
# 108   01/05/2012 12:00    -4.7              -9.6         69               20
# 109   01/05/2012 13:00    -4.4              -9.7         66               26
# 110   01/05/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
df["Weather_condition"].value_counts().head(10).plot(kind='pie');
