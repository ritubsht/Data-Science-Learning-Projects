# %%
import pandas as pd
df=pd.read_csv("dirty_cafe_sales.csv")

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 2       TXN_4271903    Cookie        4              1       ERROR
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2              2           4
# 9996    TXN_9659401       NaN        3            NaN           3
# 9997    TXN_5255387    Coffee        4              2           8
# 9998    TXN_7695629    Cookie        3            NaN           3
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df["Quantity"].unique()
# Out:
# array(['2', '4', '5', '3', '1', 'ERROR', 'UNKNOWN', nan], dtype=object)

# %%
df=df.drop(df[df["Quantity"]=="UNKNOWN"].index)

# %%
df=df.drop(df[df["Quantity"]=="ERROR"].index)

# %%
df["Quantity"].unique()
# Out:
# array(['2', '4', '5', '3', '1', nan], dtype=object)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 2       TXN_4271903    Cookie        4              1       ERROR
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2              2           4
# 9996    TXN_9659401       NaN        3            NaN           3
# 9997    TXN_5255387    Coffee        4              2           8
# 9998    TXN_7695629    Cookie        3            NaN           3
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 2       TXN_4271903    Cookie        4              1       ERROR
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# ...             ...       ...      ...            ...         ...
# 9979    TXN_9933628  Smoothie        5              4          20
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9992    TXN_2739140  Smoothie        4              4          16
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df["Quantity"].unique()
# Out:
# array(['2', '4', '3', '5', '1'], dtype=object)

# %%
df["Item"].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'UNKNOWN', 'Sandwich',
#        'Juice', 'Smoothie', 'ERROR', 'Tea'], dtype=object)

# %%
df=df.drop(df[df["Item"]=="ERROR"].index)

# %%
df=df.drop(df[df["Item"]=="UNKNOWN"].index)

# %%
df["Item"].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Sandwich', 'Juice',
#        'Smoothie', 'Tea'], dtype=object)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 2       TXN_4271903    Cookie        4              1       ERROR
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# ...             ...       ...      ...            ...         ...
# 9979    TXN_9933628  Smoothie        5              4          20
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9992    TXN_2739140  Smoothie        4              4          16
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df["Price Per Unit"].unique()
# Out:
# array(['2', '3', '1', '5', '4', '1.5', 'UNKNOWN', 'ERROR'], dtype=object)

# %%
df=df.drop(df[df["Price Per Unit"]=="ERROR"].index)

# %%
df=df.drop(df[df["Price Per Unit"]=="UNKNOWN"].index)

# %%
df["Price Per Unit"].unique()
# Out:
# array(['2', '3', '1', '5', '4', '1.5'], dtype=object)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 2       TXN_4271903    Cookie        4              1       ERROR
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# ...             ...       ...      ...            ...         ...
# 9979    TXN_9933628  Smoothie        5              4          20
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9992    TXN_2739140  Smoothie        4              4          16
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df["Total Spent"].unique()
# Out:
# array(['4', '12', 'ERROR', '10', '16', '25', '8', '15', '6', '20', '5',
#        '1', '3', '2', '9', 'UNKNOWN', '7.5', '4.5', '1.5'], dtype=object)

# %%
df=df.drop(df[df["Total Spent"]=="ERROR"].index)

# %%
df=df.drop(df[df["Total Spent"]=="UNKNOWN"].index)

# %%
df["Total Spent"].unique()
# Out:
# array(['4', '12', '10', '16', '25', '8', '15', '6', '20', '5', '1', '3',
#        '2', '9', '7.5', '4.5', '1.5'], dtype=object)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 3       TXN_7034554     Salad        2              5          10
# 4       TXN_3160411    Coffee        2              2           4
# 7       TXN_6699534  Sandwich        4              4          16
# ...             ...       ...      ...            ...         ...
# 9979    TXN_9933628  Smoothie        5              4          20
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9992    TXN_2739140  Smoothie        4              4          16
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df["Payment Method"].unique()
# Out:
# array(['Credit Card', 'Cash', 'UNKNOWN', 'Digital Wallet', 'ERROR'],
#       dtype=object)

# %%
df=df.drop(df[df["Payment Method"]=="ERROR"].index)

# %%
df=df.drop(df[df["Payment Method"]=="UNKNOWN"].index)

# %%
df["Payment Method"].unique()
# Out:
# array(['Credit Card', 'Cash', 'Digital Wallet'], dtype=object)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 4       TXN_3160411    Coffee        2              2           4
# 7       TXN_6699534  Sandwich        4              4          16
# 10      TXN_2548360     Salad        5              5          25
# ...             ...       ...      ...            ...         ...
# 9975    TXN_9668108      Cake        1              3           3
# 9979    TXN_9933628  Smoothie        5              4          20
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df["Location"].unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN', 'ERROR'], dtype=object)

# %%
df=df.drop(df[df["Location"]=="ERROR"].index)

# %%
df=df.drop(df[df["Location"]=="UNKNOWN"].index)

# %%
df["Location"].unique()
# Out:
# array(['Takeaway', 'In-store'], dtype=object)

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 4       TXN_3160411    Coffee        2              2           4
# 10      TXN_2548360     Salad        5              5          25
# 11      TXN_3051279  Sandwich        2              4           8
# ...             ...       ...      ...            ...         ...
# 9975    TXN_9668108      Cake        1              3           3
# 9979    TXN_9933628  Smoothie        5              4          20
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df["Transaction Date"].unique()
# Out:
# array(['08/09/2023', '16/05/2023', '11/06/2023', '07/11/2023', 'ERROR',
#        '03/05/2023', '15/11/2023', '24/02/2023', '15/01/2023',
#        '30/03/2023', '01/12/2023', '03/06/2023', '20/04/2023',
#        '10/04/2023', '09/10/2023', '29/04/2023', '03/11/2023',
#        '05/12/2023', '03/10/2023', '22/03/2023', '31/01/2023',
#        '16/07/2023', '15/06/2023', '09/12/2023', '28/10/2023',
#        '16/08/2023', '10/06/2023', '15/04/2023', '27/05/2023',
#        '25/07/2023', '15/12/2023', '28/12/2023', 'UNKNOWN', '23/09/2023',
#        '14/09/2023', '06/02/2023', '11/03/2023', '14/07/2023',
#        '18/04/2023', '12/12/2023', '05/01/2023', '23/03/2023',
#        '30/04/2023', '25/11/2023', '21/05/2023', '02/07/2023',
#        '21/11/2023', '13/03/2023', '16/02/2023', '01/11/2023',
#        '28/02/2023', '07/04/2023', '10/12/2023', '04/02/2023',
#        '10/05/2023', '26/04/2023', '28/05/2023', '01/03/2023',
#        '13/11/2023', '27/12/2023', '18/05/2023', '22/09/2023',
# ...

# %%
df=df.drop(df[df["Transaction Date"]=="ERROR"].index)

# %%
df=df.drop(df[df["Transaction Date"]=="UNKNOWN"].index)

# %%
df["Transaction Date"].unique()
# Out:
# array(['08/09/2023', '16/05/2023', '11/06/2023', '07/11/2023',
#        '03/05/2023', '15/11/2023', '24/02/2023', '15/01/2023',
#        '30/03/2023', '01/12/2023', '03/06/2023', '20/04/2023',
#        '10/04/2023', '09/10/2023', '29/04/2023', '03/11/2023',
#        '05/12/2023', '03/10/2023', '22/03/2023', '31/01/2023',
#        '16/07/2023', '15/06/2023', '09/12/2023', '28/10/2023',
#        '16/08/2023', '10/06/2023', '15/04/2023', '27/05/2023',
#        '25/07/2023', '15/12/2023', '28/12/2023', '23/09/2023',
#        '14/09/2023', '06/02/2023', '11/03/2023', '14/07/2023',
#        '18/04/2023', '12/12/2023', '05/01/2023', '23/03/2023',
#        '30/04/2023', '25/11/2023', '21/05/2023', '02/07/2023',
#        '21/11/2023', '13/03/2023', '16/02/2023', '01/11/2023',
#        '28/02/2023', '07/04/2023', '10/12/2023', '04/02/2023',
#        '10/05/2023', '26/04/2023', '28/05/2023', '01/03/2023',
#        '13/11/2023', '27/12/2023', '18/05/2023', '22/09/2023',
# ...

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2              2           4
# 1       TXN_4977031      Cake        4              3          12
# 4       TXN_3160411    Coffee        2              2           4
# 10      TXN_2548360     Salad        5              5          25
# 12      TXN_7619095  Sandwich        2              4           8
# ...             ...       ...      ...            ...         ...
# 9975    TXN_9668108      Cake        1              3           3
# 9979    TXN_9933628  Smoothie        5              4          20
# 9986    TXN_2858441  Sandwich        2              4           8
# 9991    TXN_3897619  Sandwich        3              4          12
# 9999    TXN_6170729  Sandwich        3              4          12
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# ...

# %%
df["Quantity"]=df["Quantity"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3089 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    3089 non-null   object
#  1   Item              3089 non-null   object
#  2   Quantity          3089 non-null   int64
#  3   Price Per Unit    3089 non-null   object
#  4   Total Spent       3089 non-null   object
#  5   Payment Method    3089 non-null   object
#  6   Location          3089 non-null   object
#  7   Transaction Date  3089 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 217.2+ KB

# %%
df["Price Per Unit"]=df["Price Per Unit"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3089 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    3089 non-null   object
#  1   Item              3089 non-null   object
#  2   Quantity          3089 non-null   int64
#  3   Price Per Unit    3089 non-null   float64
#  4   Total Spent       3089 non-null   object
#  5   Payment Method    3089 non-null   object
#  6   Location          3089 non-null   object
#  7   Transaction Date  3089 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 217.2+ KB

# %%
df["Total Spent"]=df["Total Spent"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3089 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    3089 non-null   object
#  1   Item              3089 non-null   object
#  2   Quantity          3089 non-null   int64
#  3   Price Per Unit    3089 non-null   float64
#  4   Total Spent       3089 non-null   float64
#  5   Payment Method    3089 non-null   object
#  6   Location          3089 non-null   object
#  7   Transaction Date  3089 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 217.2+ KB

# %%
df.sample(20)
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 2964    TXN_7321789     Juice         3             3.0          9.0
# 3860    TXN_8294790    Cookie         1             1.0          1.0
# 8938    TXN_3426338     Salad         1             5.0          5.0
# 5837    TXN_5318263  Smoothie         1             4.0          4.0
# 9243    TXN_4508067  Smoothie         5             4.0         20.0
# 1352    TXN_2385697    Coffee         1             2.0          2.0
# 4910    TXN_6546131    Coffee         4             2.0          8.0
# 8964    TXN_2713279    Cookie         4             1.0          4.0
# 9289    TXN_2014042    Cookie         4             1.0          4.0
# 5975    TXN_4336291     Salad         5             5.0         25.0
# 7365    TXN_6018020    Cookie         2             1.0          2.0
# 3061    TXN_4708410      Cake         4             3.0         12.0
# 4829    TXN_3394874    Coffee         4             2.0          8.0
# ...

# %%
df.shape
# Out:
# (3089, 8)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Transaction ID      3089
# Item                   8
# Quantity               5
# Price Per Unit         6
# Total Spent           17
# Payment Method         3
# Location               2
# Transaction Date     365
# dtype: int64

# %%
df.count()
# Out:
# Transaction ID      3089
# Item                3089
# Quantity            3089
# Price Per Unit      3089
# Total Spent         3089
# Payment Method      3089
# Location            3089
# Transaction Date    3089
# dtype: int64

# %%
df["Item"].value_counts()
# Out:
# Item
# Juice       427
# Salad       418
# Cookie      391
# Sandwich    391
# Cake        385
# Tea         372
# Coffee      367
# Smoothie    338
# Name: count, dtype: int64

# %%
df[df.Item=="Juice"]
#df.groupby('Item').get_group('Juice')
# Out:
#      Transaction ID   Item  Quantity  Price Per Unit  Total Spent  \
# 17      TXN_6769710  Juice         2             3.0          6.0
# 19      TXN_3709394  Juice         4             3.0         12.0
# 27      TXN_5695074  Juice         4             3.0         12.0
# 46      TXN_8078640  Juice         4             3.0         12.0
# 79      TXN_3829165  Juice         4             3.0         12.0
# ...             ...    ...       ...             ...          ...
# 9873    TXN_8270768  Juice         5             3.0         15.0
# 9898    TXN_8999360  Juice         3             3.0          9.0
# 9899    TXN_6188262  Juice         1             3.0          3.0
# 9941    TXN_4224427  Juice         4             3.0         12.0
# 9959    TXN_4556831  Juice         2             3.0          6.0
#
#       Payment Method  Location Transaction Date
# 17              Cash  In-store       24/02/2023
# 19              Cash  Takeaway       15/01/2023
# ...

# %%
len(df[df.Item=="Juice"])
# Out:
# 427

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Transaction ID      3089
# Item                3089
# Quantity            3089
# Price Per Unit      3089
# Total Spent         3089
# Payment Method      3089
# Location            3089
# Transaction Date    3089
# dtype: int64

# %%
df.rename(columns={"Quantity":"Qty"})
# Out:
#      Transaction ID      Item  Qty  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee    2             2.0          4.0
# 1       TXN_4977031      Cake    4             3.0         12.0
# 4       TXN_3160411    Coffee    2             2.0          4.0
# 10      TXN_2548360     Salad    5             5.0         25.0
# 12      TXN_7619095  Sandwich    2             4.0          8.0
# ...             ...       ...  ...             ...          ...
# 9975    TXN_9668108      Cake    1             3.0          3.0
# 9979    TXN_9933628  Smoothie    5             4.0         20.0
# 9986    TXN_2858441  Sandwich    2             4.0          8.0
# 9991    TXN_3897619  Sandwich    3             4.0         12.0
# 9999    TXN_6170729  Sandwich    3             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       08/09/2023
# 1               Cash  In-store       16/05/2023
# 4     Digital Wallet  In-store       11/06/2023
# ...

# %%
#df.Quantity.mean()
df["Quantity"].mean()
# Out:
# np.float64(3.0236322434444802)

# %%
df.Quantity.median()
# Out:
# np.float64(3.0)

# %%
df[(df["Item"]=="Juice") & (df["Quantity"]>4)]
# Out:
#      Transaction ID   Item  Quantity  Price Per Unit  Total Spent  \
# 133     TXN_1150033  Juice         5             3.0         15.0
# 436     TXN_6769465  Juice         5             3.0         15.0
# 473     TXN_8502094  Juice         5             3.0         15.0
# 540     TXN_3917193  Juice         5             3.0         15.0
# 637     TXN_8958593  Juice         5             3.0         15.0
# ...             ...    ...       ...             ...          ...
# 9594    TXN_6403012  Juice         5             3.0         15.0
# 9729    TXN_5563486  Juice         5             3.0         15.0
# 9773    TXN_6091542  Juice         5             3.0         15.0
# 9828    TXN_4606893  Juice         5             3.0         15.0
# 9873    TXN_8270768  Juice         5             3.0         15.0
#
#       Payment Method  Location Transaction Date
# 133             Cash  In-store       18/04/2023
# 436   Digital Wallet  In-store       13/06/2023
# ...

# %%
df.groupby("Item").mean('numeric_only')
# Out:
#           Quantity  Price Per Unit  Total Spent
# Item
# Cake      3.046753             3.0     9.140260
# Coffee    3.054496             2.0     6.108992
# Cookie    2.974425             1.0     2.974425
# Juice     2.915691             3.0     8.747073
# Salad     3.043062             5.0    15.215311
# Sandwich  3.051151             4.0    12.204604
# Smoothie  3.023669             4.0    12.094675
# Tea       3.094086             1.5     4.641129

# %%
df.groupby("Item").agg(['min', 'max'])
# Out:
#          Transaction ID              Quantity     Price Per Unit       \
#                     min          max      min max            min  max
# Item
# Cake        TXN_1011236  TXN_9991225        1   5            3.0  3.0
# Coffee      TXN_1005331  TXN_9954652        1   5            2.0  2.0
# Cookie      TXN_1002457  TXN_9987017        1   5            1.0  1.0
# Juice       TXN_1057760  TXN_9999113        1   5            3.0  3.0
# Salad       TXN_1006942  TXN_9884180        1   5            5.0  5.0
# Sandwich    TXN_1045022  TXN_9983356        1   5            4.0  4.0
# Smoothie    TXN_1004184  TXN_9989719        1   5            4.0  4.0
# Tea         TXN_1000555  TXN_9992148        1   5            1.5  1.5
#
#          Total Spent       Payment Method                  Location            \
#                  min   max            min             max       min       max
# Item
# Cake             3.0  15.0           Cash  Digital Wallet  In-store  Takeaway
# ...

# %%
df[df["Payment Method"].str.contains("Cash")]
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 1       TXN_4977031      Cake         4             3.0         12.0
# 10      TXN_2548360     Salad         5             5.0         25.0
# 12      TXN_7619095  Sandwich         2             4.0          8.0
# 17      TXN_6769710     Juice         2             3.0          6.0
# 19      TXN_3709394     Juice         4             3.0         12.0
# ...             ...       ...       ...             ...          ...
# 9974    TXN_8076061       Tea         4             1.5          6.0
# 9975    TXN_9668108      Cake         1             3.0          3.0
# 9979    TXN_9933628  Smoothie         5             4.0         20.0
# 9991    TXN_3897619  Sandwich         3             4.0         12.0
# 9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#      Payment Method  Location Transaction Date
# 1              Cash  In-store       16/05/2023
# ...

# %%
df[(df["Item"]=="Juice") | (df["Quantity"]>3)]
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 1       TXN_4977031      Cake         4             3.0         12.0
# 10      TXN_2548360     Salad         5             5.0         25.0
# 17      TXN_6769710     Juice         2             3.0          6.0
# 19      TXN_3709394     Juice         4             3.0         12.0
# 21      TXN_3567645  Smoothie         4             4.0         16.0
# ...             ...       ...       ...             ...          ...
# 9962    TXN_4723089  Sandwich         4             4.0         16.0
# 9970    TXN_5762440  Sandwich         5             4.0         20.0
# 9971    TXN_6120851     Salad         5             5.0         25.0
# 9974    TXN_8076061       Tea         4             1.5          6.0
# 9979    TXN_9933628  Smoothie         5             4.0         20.0
#
#      Payment Method  Location Transaction Date
# 1              Cash  In-store       16/05/2023
# ...

# %%
df["Transaction Date"].unique()
# Out:
# array(['08/09/2023', '16/05/2023', '11/06/2023', '07/11/2023',
#        '03/05/2023', '15/11/2023', '24/02/2023', '15/01/2023',
#        '30/03/2023', '01/12/2023', '03/06/2023', '20/04/2023',
#        '10/04/2023', '09/10/2023', '29/04/2023', '03/11/2023',
#        '05/12/2023', '03/10/2023', '22/03/2023', '31/01/2023',
#        '16/07/2023', '15/06/2023', '09/12/2023', '28/10/2023',
#        '16/08/2023', '10/06/2023', '15/04/2023', '27/05/2023',
#        '25/07/2023', '15/12/2023', '28/12/2023', '23/09/2023',
#        '14/09/2023', '06/02/2023', '11/03/2023', '14/07/2023',
#        '18/04/2023', '12/12/2023', '05/01/2023', '23/03/2023',
#        '30/04/2023', '25/11/2023', '21/05/2023', '02/07/2023',
#        '21/11/2023', '13/03/2023', '16/02/2023', '01/11/2023',
#        '28/02/2023', '07/04/2023', '10/12/2023', '04/02/2023',
#        '10/05/2023', '26/04/2023', '28/05/2023', '01/03/2023',
#        '13/11/2023', '27/12/2023', '18/05/2023', '22/09/2023',
# ...

# %%
df["Transaction Date"]= pd.to_datetime(df["Transaction Date"],format='%d/%m/%Y')

# %%
df["MONTH"]=df["Transaction Date"].dt.month

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee         2             2.0          4.0
# 1       TXN_4977031      Cake         4             3.0         12.0
# 4       TXN_3160411    Coffee         2             2.0          4.0
# 10      TXN_2548360     Salad         5             5.0         25.0
# 12      TXN_7619095  Sandwich         2             4.0          8.0
# ...             ...       ...       ...             ...          ...
# 9975    TXN_9668108      Cake         1             3.0          3.0
# 9979    TXN_9933628  Smoothie         5             4.0         20.0
# 9986    TXN_2858441  Sandwich         2             4.0          8.0
# 9991    TXN_3897619  Sandwich         3             4.0         12.0
# 9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#       Payment Method  Location Transaction Date  MONTH
# 0        Credit Card  Takeaway       2023-09-08      9
# ...

# %%
df["MONTH"]=df["MONTH"].astype(int)

# %%
df.MONTH.unique()
# Out:
# array([ 9,  5,  6, 11,  2,  1,  3, 12,  4, 10,  7,  8])

# %%
df.groupby('MONTH')['Total Spent'].sum()
# Out:
# MONTH
# 1     2749.0
# 2     2219.5
# 3     2240.0
# 4     2275.5
# 5     1844.5
# 6     2281.5
# 7     2307.0
# 8     2328.5
# 9     2426.5
# 10    2309.5
# 11    2397.0
# 12    2227.0
# Name: Total Spent, dtype: float64
