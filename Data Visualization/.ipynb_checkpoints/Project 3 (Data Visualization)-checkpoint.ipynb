# %%
import pandas as pd
df=pd.read_csv("Netflix Dataset.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
#1
a=df.groupby('Title').get_group('House of Cards')
a[['Show_Id','Director']]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
df=df.copy()
df["Release_Date"]= pd.to_datetime(df["Release_Date"],format='mixed')

# %%
df["Year"]=df["Release_Date"].dt.year

# %%
df
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
#2
df.groupby('Category')['Year'].value_counts().plot(kind='bar');

# %%
df['Release_Date'].dt.year.value_counts()
# Out:
# Release_Date
# 2019    1338
# 2020    1230
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: count, dtype: int64

# %%
df['Release_Date'].dt.year.value_counts().plot(kind='bar');

# %%
#2
df.groupby('Category')['Year'].value_counts().sort_values(ascending=False).reset_index()
# Out:
#    Category  Year  count
# 0     Movie  2019   1310
# 1     Movie  2020   1178
# 2     Movie  2018   1098
# 3     Movie  2017    727
# 4     Movie  2016    200
# 5     Movie  2021     75
# 6   TV Show  2020     52
# 7     Movie  2015     47
# 8   TV Show  2019     28
# 9   TV Show  2017     25
# 10  TV Show  2018     17
# 11    Movie  2014     14
# 12    Movie  2011     13
# 13  TV Show  2016      7
# 14    Movie  2013      6
# 15  TV Show  2015      3
# 16  TV Show  2021      3
# 17    Movie  2012      3
# 18    Movie  2009      2
# 19    Movie  2008      1
# 20    Movie  2010      1
# 21  TV Show  2013      1

# %%
#3
df.Category.value_counts()
# Out:
# Category
# Movie      4675
# TV Show     136
# Name: count, dtype: int64

# %%
#3
import matplotlib as plt
import seaborn as sns
ax=sns.countplot(x='Category',data=df)
for bar in ax.containers:
    ax.bar_label(bar)

# %%
#4
df.Year.unique()
# Out:
# array([2016, 2018, 2017, 2020, 2019, 2021, 2015, 2013, 2011, 2012, 2014,
#        2009, 2010, 2008], dtype=int32)

# %%
#5
a=df[(df['Country']=='India') & (df['Category']=='Tv Show')]
a[['Title']]
# Out:
# Empty DataFrame
# Columns: [Title]
# Index: []

# %%
#6
df.groupby('Director')['Category'].count().sort_values(ascending=False).head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: Category, dtype: int64

# %%
#7
df[(df['Category']=='Movie') & ((df['Type']=='Comedies') | (df['Country']=='United Kingdom'))]
# Out:
#      Show_Id Category                       Title  \
# 33       s34    Movie                #realityhigh
# 72       s73    Movie                    17 Again
# 82       s83    Movie         2036 Origin Unknown
# 84       s85    Movie                   21 & Over
# 93       s94    Movie           27: Gone Too Soon
# ...      ...      ...                         ...
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7623   s7622    Movie                   Wild Oats
# 7634   s7633    Movie                Wine Country
# 7664   s7663    Movie                     Work It
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 33                          Fernando Lebrija
# 72                               Burr Steers
# 82                             Hasraf Dulull
# 84                    Jon Lucas, Scott Moore
# 93                         Simon Napier-Bell
# ...                                      ...
# ...

# %%
#8
df["Cast"].str.contains("Tom Cruise").value_counts()
# Out:
# Cast
# False    4809
# True        2
# Name: count, dtype: int64

# %%
#9
df.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#9.1
len(df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')])
# Out:
# 9

# %%
#9.2
len(df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Year']>2018)])
# Out:
# 0

# %%
df["Duration"] = df["Duration"].str.replace("min","")

# %%
df["Duration"] = df["Duration"].str.replace("Seasons","")

# %%
df["Duration"] = df["Duration"].str.replace("Season","")

# %%
df["Duration"] = df["Duration"].str.replace(" ","")

# %%
df.Duration.unique()
# Out:
# array(['93', '78', '80', '123', '1', '95', '119', '118', '143', '103',
#        '89', '91', '149', '144', '124', '110', '128', '117', '100', '99',
#        '102', '104', '105', '125', '81', '97', '106', '107', '87', '109',
#        '101', '90', '113', '114', '130', '94', '140', '135', '82', '70',
#        '92', '164', '83', '116', '84', '86', '120', '96', '126', '75',
#        '129', '77', '137', '148', '121', '122', '176', '85', '22', '68',
#        '111', '29', '142', '168', '59', '108', '44', '26', '156', '98',
#        '57', '150', '133', '115', '154', '127', '146', '136', '88', '131',
#        '2', '24', '112', '74', '63', '174', '60', '153', '158', '151',
#        '162', '54', '51', '69', '64', '147', '42', '79', '45', '172',
#        '53', '163', '55', '61', '71', '160', '171', '30', '48', '139',
#        '157', '15', '72', '134', '161', '62', '8', '186', '49', '73',
#        '58', '65', '165', '159', '141', '132', '166', '76', '25', '56',
# ...

# %%
df["Duration"]=df["Duration"].astype(int)

# %%
#10
df.Duration.max()
# Out:
# np.int64(253)

# %%
#11
m=df[(df['Category']=='TV Show')]
m.groupby("Country")['Category'].value_counts().sort_values(ascending=False).head(1)
# Out:
# Country        Category
# United States  TV Show     27
# Name: count, dtype: int64

# %%
#12
df.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                                       Title  \
# 6289   s6289    Movie                                The Departed
# 5771   s5771    Movie                             Spring Breakers
# 493     s494    Movie                         An Imperfect Murder
# 5521   s5521    Movie                          Sex and the City 2
# 5564   s5564    Movie                             Sherlock Holmes
# ...      ...      ...                                         ...
# 5042   s5042    Movie  Quiet Victory: The Charlie Wedemeyer Story
# 3840   s3841    Movie                 Mad Ron's Prevues from Hell
# 5766   s5766    Movie                                    Splatter
# 3248   s3249    Movie                     Just Another Love Story
# 7115   s7114    Movie                        To and From New York
#
#                   Director                                               Cast  \
# 6289       Martin Scorsese  Leonardo DiCaprio, Matt Damon, Jack Nicholson,...
# ...

# %%
#13
df[(df['Category']=='Movie') & (df['Type']=='Dramas') | (df['Category']=='TV Show') & (df['Type']=="Kids'TV")]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
