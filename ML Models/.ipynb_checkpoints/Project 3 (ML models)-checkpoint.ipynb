# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
df=pd.read_csv('canada_per_capita_income.csv')

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df[df["year"]==2020]
# Out:
# Empty DataFrame
# Columns: [year, per capita income (US$)]
# Index: []

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]
#X=df["year"]

# %%
X
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (37, 1)

# %%
X_test.shape
# Out:
# (10, 1)

# %%
from sklearn.linear_model import LinearRegression
model=make_pipeline(PolynomialFeatures(degree=2),LinearRegression())

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
k=KNeighborsRegressor(n_neighbors=3)
k.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
X_train
# Out:
#     year
# 2   1972
# 9   1979
# 17  1987
# 30  2000
# 25  1995
# 44  2014
# 29  1999
# 27  1997
# 1   1971
# 24  1994
# 33  2003
# 38  2008
# 19  1989
# 36  2006
# 10  1980
# 4   1974
# 6   1976
# 3   1973
# 39  2009
# 5   1975
# 32  2002
# 28  1998
# 20  1990
# 26  1996
# 37  2007
# 21  1991
# 41  2011
# 31  2001
# 34  2004
# 7   1977
# 46  2016
# 11  1981
# 18  1988
# 22  1992
# 8   1978
# 15  1985
# 40  2010

# %%
X_test
# Out:
#     year
# 23  1993
# 12  1982
# 42  2012
# 16  1986
# 35  2005
# 43  2013
# 45  2015
# 13  1983
# 14  1984
# 0   1970

# %%
y_test
# Out:
# 23    15875.586730
# 12     9619.438377
# 42    42665.255970
# 16    11482.891530
# 35    29198.055690
# 43    42676.468370
# 45    35175.188980
# 13    10416.536590
# 14    10790.328720
# 0      3399.299037
# Name: per capita income (US$), dtype: float64

# %%
lr.predict(X_test)
# Out:
# array([18602.90731472,  9836.602296  , 33744.7068925 , 13024.34957553,
#        28166.14915331, 34541.64371238, 36135.51735215, 10633.53911588,
#        11430.47593577,   273.3604574 ])

# %%
new_year=lr.predict([[2020]])
new_year
# Out:
# C:\Users\SOS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40120.20145156])

# %%
k.predict(X_test)
# Out:
# array([16179.07353667,  8464.42381767, 40598.3759    , 13024.68197333,
#        27065.61211   , 39201.26614667, 39201.26614667,  9603.104874  ,
#        11142.71770733,  4274.64555567])

# %%
model.predict(X_test)
# Out:
# array([16076.83663541,  8849.78215751, 36936.76451965, 11066.30837815,
#        28017.04716225, 38328.57945343, 41200.38651872,  9359.82511379,
#         9899.26046933,  5021.87382349])

# %%
plt.scatter(data=df, x='year', y='per capita income (US$)')
plt.plot(X_test,lr.predict(X_test), color="r")

plt.xlabel("YEAR")
plt.ylabel("PER CAPITA INCOME")
plt.title("GRAPH")
plt.grid()

plt.show()

# %%
plt.scatter(data=df, x='year', y='per capita income (US$)')
plt.plot(X_test,k.predict(X_test), color="r")

plt.xlabel("YEAR")
plt.ylabel("PER CAPITA INCOME")
plt.title("GRAPH")
plt.grid()

plt.show()

# %%
plt.scatter(data=df, x='year', y='per capita income (US$)')
plt.plot(X_test,model.predict(X_test), color="r")

plt.xlabel("YEAR")
plt.ylabel("PER CAPITA INCOME")
plt.title("GRAPH")
plt.grid()

plt.show()
