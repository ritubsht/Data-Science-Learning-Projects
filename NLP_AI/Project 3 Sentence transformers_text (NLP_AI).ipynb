# %%
# !pip install --upgrade pip
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: pip in /home/ritu-bisht/venv/lib/python3.12/site-packages (25.3)
# Requirement already satisfied: sentence-transformers in /home/ritu-bisht/venv/lib/python3.12/site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: scikit-learn in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /home/ritu-bisht/venv/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipywidgets) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in /home/ritu-bisht/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /home/ritu-bisht/venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/ritu-bisht/venv/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in /home/ritu-bisht/venv/lib/python3.12/site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: pillow in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in /home/ritu-bisht/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.2.0)
# Requirement already satisfied: namex in /home/ritu-bisht/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /home/ritu-bisht/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/ritu-bisht/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)

# %%
import numpy as np
import torch
from sentence_transformers import SentenceTransformer, util
# Out:
# 2025-11-13 15:34:34.891877: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model=SentenceTransformer("all-MiniLM-L6-v2")

# %%
#cosine similarity measures how close two embeddings are
sentences=["I love playing cricket", "i am fine."]
#GENERATE EMBEDDINGS
embeddings=model.encode(sentences)
print("Sentence Embeddings Shape:",embeddings.shape)
# Out:
# Sentence Embeddings Shape: (2, 384)

# %%
#calculate similarity btw two sentences
similarity_score=util.cos_sim(embeddings[0],embeddings[1])
print(f"cosine similarity:{similarity_score.item():.4f}")
# Out:
# cosine similarity:0.1219

# %%
sentences=["I love playing cricket", "I love playing CRICKET.,"]
#GENERATE EMBEDDINGS
embeddings=model.encode(sentences)
print("Sentence Embeddings Shape:",embeddings.shape)
# Out:
# Sentence Embeddings Shape: (2, 384)

# %%
#calculate similarity btw two sentences
similarity_score=util.cos_sim(embeddings[0],embeddings[1])
print(f"cosine similarity:{similarity_score.item():.4f}")
# Out:
# cosine similarity:0.9745

# %%
keywords = [
    "artificial intelligence", "machine learning", "blockchain", "cybersecurity",
    "software engineering", "football", "basketball", "Olympics", "athletics",
    "fitness", "election", "policy", "diplomacy", "legislation", "foreign relations",
    "biology", "physics", "chemistry", "genetics", "astronomy", "healthcare",
    "finance", "economics", "environment", "entertainment", "education", "psychology"]

# %%
while True:
    content= input("Input text to getkeywords or press(exit):")
    print("\n--------------------------------------------------------------------------------")
    if content=="exit" or content=="Exit" :
        break
    else:
        top_keywords=extract_top_keywords(content,keywords,top_n=2)
        print("Your content------->",content[:40], "**************", content[-40:],"\n")
        print("Top keywords------->", top_keywords, "\n")
# Out:
# Input text to getkeywords or press(exit): exit
# --------------------------------------------------------------------------------
